# %%
#basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#ML libraries
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import StandardScaler, OneHotEncoder 
import sys
sys.path.append('../src')
import optuna
import joblib
RANDOM_STATE = 42

# %%
# Load preprocessed data
df = pd.read_csv("../../data/X_train_preprocessed.csv")

# %%
# Define features and target
target = "PrimeCommerciale"
X = df.drop(columns=[target])
y = df[target]

# %%
# split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.2, random_state=RANDOM_STATE
 )

# %%
var_num = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
var_cat = X.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
# Define preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
         ('num', StandardScaler(), var_num),           
         ('cat', OneHotEncoder(handle_unknown='ignore'), var_cat)
     ]
 )

# %%
# Evaluation function
def evaluate_regression(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    return rmse, r2

# %%
# ===========================
# Optuna objective for XGBoost
# ===========================
def objective_xgb(trial):
    n_estimators = trial.suggest_int("n_estimators", 100, 500)
    max_depth = trial.suggest_int("max_depth", 3, 10)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 0.2)
    subsample = trial.suggest_float("subsample", 0.5, 1.0)
    colsample_bytree = trial.suggest_float("colsample_bytree", 0.5, 1.0)
    
    model = Pipeline([
        ('preprocess', preprocessor),
        ('model', XGBRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            objective='reg:squarederror',
            random_state=42
        ))
    ])
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    rmse, _ = evaluate_regression(y_test, y_pred)
    return rmse

# Optuna study for XGBoost
study_xgb = optuna.create_study(direction="minimize")
study_xgb.optimize(objective_xgb, n_trials=30)

print("Best XGB params:", study_xgb.best_params)

# Train best XGBoost model
best_xgb = Pipeline([
    ('preprocess', preprocessor),
    ('model', XGBRegressor(**study_xgb.best_params, objective='reg:squarederror', random_state=42))
])
best_xgb.fit(X_train, y_train)
y_pred_xgb = best_xgb.predict(X_test)
rmse_xgb, r2_xgb = evaluate_regression(y_test, y_pred_xgb)
print(f"\nXGBoost Regressor --> RMSE: {rmse_xgb:.4f}, R2: {r2_xgb:.4f}")
# Out:
# [I 2025-12-23 22:55:40,361] A new study created in memory with name: no-name-743fc8ee-e7ca-4702-8923-d35a31abc8e9
# [I 2025-12-23 22:55:40,994] Trial 0 finished with value: 107.65372968301192 and parameters: {'n_estimators': 169, 'max_depth': 8, 'learning_rate': 0.04757170948730508, 'subsample': 0.8018012801794322, 'colsample_bytree': 0.572660232770942}. Best is trial 0 with value: 107.65372968301192.
# [I 2025-12-23 22:55:42,163] Trial 1 finished with value: 115.45452326994757 and parameters: {'n_estimators': 302, 'max_depth': 8, 'learning_rate': 0.010168450872262837, 'subsample': 0.7853784768029484, 'colsample_bytree': 0.5553982886966744}. Best is trial 0 with value: 107.65372968301192.
# [I 2025-12-23 22:55:43,304] Trial 2 finished with value: 107.09815351365413 and parameters: {'n_estimators': 364, 'max_depth': 8, 'learning_rate': 0.018392988461587708, 'subsample': 0.724758095013798, 'colsample_bytree': 0.9378601791636292}. Best is trial 2 with value: 107.09815351365413.
# [I 2025-12-23 22:55:43,740] Trial 3 finished with value: 109.70210891642574 and parameters: {'n_estimators': 290, 'max_depth': 4, 'learning_rate': 0.08411207053023721, 'subsample': 0.7151390229454799, 'colsample_bytree': 0.9018873260340925}. Best is trial 2 with value: 107.09815351365413.
# [I 2025-12-23 22:55:44,633] Trial 4 finished with value: 111.11533037602237 and parameters: {'n_estimators': 366, 'max_depth': 6, 'learning_rate': 0.17090942664619083, 'subsample': 0.5596364743030039, 'colsample_bytree': 0.8899205060121164}. Best is trial 2 with value: 107.09815351365413.
# [I 2025-12-23 22:55:46,418] Trial 5 finished with value: 111.32852896165636 and parameters: {'n_estimators': 477, 'max_depth': 8, 'learning_rate': 0.16165814190944439, 'subsample': 0.847522179915462, 'colsample_bytree': 0.6979763272237086}. Best is trial 2 with value: 107.09815351365413.
# [I 2025-12-23 22:55:47,486] Trial 6 finished with value: 107.80766912905872 and parameters: {'n_estimators': 278, 'max_depth': 8, 'learning_rate': 0.12440667499652042, 'subsample': 0.8847000798585042, 'colsample_bytree': 0.8106359148172493}. Best is trial 2 with value: 107.09815351365413.
# [I 2025-12-23 22:55:51,084] Trial 7 finished with value: 108.47283135166349 and parameters: {'n_estimators': 442, 'max_depth': 10, 'learning_rate': 0.08559563204168882, 'subsample': 0.5008210988646218, 'colsample_bytree': 0.7984020551297699}. Best is trial 2 with value: 107.09815351365413.
# [I 2025-12-23 22:55:53,926] Trial 8 finished with value: 113.27322380612677 and parameters: {'n_estimators': 362, 'max_depth': 10, 'learning_rate': 0.1676520611215854, 'subsample': 0.6573288610545636, 'colsample_bytree': 0.5720396136897479}. Best is trial 2 with value: 107.09815351365413.
# [I 2025-12-23 22:55:55,960] Trial 9 finished with value: 106.42427644813998 and parameters: {'n_estimators': 442, 'max_depth': 8, 'learning_rate': 0.06591790128737968, 'subsample': 0.8612916311835632, 'colsample_bytree': 0.8508385726208652}. Best is trial 9 with value: 106.42427644813998.
# [I 2025-12-23 22:55:56,245] Trial 10 finished with value: 114.07058439731942 and parameters: {'n_estimators': 113, 'max_depth': 3, 'learning_rate': 0.11740670197372655, 'subsample': 0.9953678064743072, 'colsample_bytree': 0.9869460538191813}. Best is trial 9 with value: 106.42427644813998.
# [I 2025-12-23 22:55:57,300] Trial 11 finished with value: 110.98709837767517 and parameters: {'n_estimators': 404, 'max_depth': 6, 'learning_rate': 0.012972110434686664, 'subsample': 0.9236184232975493, 'colsample_bytree': 0.9986768931219467}. Best is trial 9 with value: 106.42427644813998.
# [I 2025-12-23 22:55:59,325] Trial 12 finished with value: 106.1645504217598 and parameters: {'n_estimators': 488, 'max_depth': 7, 'learning_rate': 0.0465993926653307, 'subsample': 0.6903876261245432, 'colsample_bytree': 0.8873702240299636}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:00,638] Trial 13 finished with value: 107.86707303100098 and parameters: {'n_estimators': 478, 'max_depth': 5, 'learning_rate': 0.054774242003118236, 'subsample': 0.6414541657177826, 'colsample_bytree': 0.7099676069882721}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:02,130] Trial 14 finished with value: 106.49138077451323 and parameters: {'n_estimators': 417, 'max_depth': 7, 'learning_rate': 0.05423886139722796, 'subsample': 0.6681867339404304, 'colsample_bytree': 0.8315445242041377}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:06,316] Trial 15 finished with value: 107.75929150873102 and parameters: {'n_estimators': 495, 'max_depth': 9, 'learning_rate': 0.08365854494942632, 'subsample': 0.9616077457987519, 'colsample_bytree': 0.7625696921397059}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:07,453] Trial 16 finished with value: 107.87118382496368 and parameters: {'n_estimators': 219, 'max_depth': 7, 'learning_rate': 0.03664769272921645, 'subsample': 0.8387804488764362, 'colsample_bytree': 0.8497390658330545}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:08,717] Trial 17 finished with value: 107.73455471275528 and parameters: {'n_estimators': 437, 'max_depth': 5, 'learning_rate': 0.07300423475623069, 'subsample': 0.6067254518195344, 'colsample_bytree': 0.6464204970425969}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:10,940] Trial 18 finished with value: 111.22155317444401 and parameters: {'n_estimators': 325, 'max_depth': 9, 'learning_rate': 0.19627806446881288, 'subsample': 0.7628235602967784, 'colsample_bytree': 0.8960610265579606}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:11,868] Trial 19 finished with value: 107.52021127160242 and parameters: {'n_estimators': 238, 'max_depth': 7, 'learning_rate': 0.03431954594007155, 'subsample': 0.8962557410016498, 'colsample_bytree': 0.9402300924910758}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:14,390] Trial 20 finished with value: 107.18822132272768 and parameters: {'n_estimators': 500, 'max_depth': 9, 'learning_rate': 0.0651896258419213, 'subsample': 0.7100079015016141, 'colsample_bytree': 0.7673056662193957}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:15,717] Trial 21 finished with value: 107.67606449769468 and parameters: {'n_estimators': 412, 'max_depth': 7, 'learning_rate': 0.1052866287312143, 'subsample': 0.6738584064235272, 'colsample_bytree': 0.8385066823350851}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:16,762] Trial 22 finished with value: 107.63511127721335 and parameters: {'n_estimators': 435, 'max_depth': 6, 'learning_rate': 0.03726449192834426, 'subsample': 0.5939664762554898, 'colsample_bytree': 0.8498348771325139}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:17,760] Trial 23 finished with value: 106.3814006026662 and parameters: {'n_estimators': 392, 'max_depth': 7, 'learning_rate': 0.06395155454175526, 'subsample': 0.6818276088068698, 'colsample_bytree': 0.9388906631577552}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:18,895] Trial 24 finished with value: 107.35961798839595 and parameters: {'n_estimators': 460, 'max_depth': 6, 'learning_rate': 0.09536879064815576, 'subsample': 0.8203177720192325, 'colsample_bytree': 0.9181447843545857}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:19,723] Trial 25 finished with value: 107.99781808399423 and parameters: {'n_estimators': 387, 'max_depth': 5, 'learning_rate': 0.06760543214937004, 'subsample': 0.7496934145064592, 'colsample_bytree': 0.9664051757609733}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:22,446] Trial 26 finished with value: 109.82803182875998 and parameters: {'n_estimators': 460, 'max_depth': 9, 'learning_rate': 0.1326967335808345, 'subsample': 0.6938416170137229, 'colsample_bytree': 0.8861738691599422}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:23,430] Trial 27 finished with value: 107.77231178787954 and parameters: {'n_estimators': 337, 'max_depth': 7, 'learning_rate': 0.024220263047573232, 'subsample': 0.6249490283595514, 'colsample_bytree': 0.9600702846261292}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:25,090] Trial 28 finished with value: 106.25590402221758 and parameters: {'n_estimators': 388, 'max_depth': 8, 'learning_rate': 0.06071135008171058, 'subsample': 0.5597095332983147, 'colsample_bytree': 0.8611574178185017}. Best is trial 12 with value: 106.1645504217598.
# [I 2025-12-23 22:56:26,460] Trial 29 finished with value: 106.7325528332257 and parameters: {'n_estimators': 385, 'max_depth': 7, 'learning_rate': 0.04814777387111569, 'subsample': 0.5491748456160881, 'colsample_bytree': 0.789501897038454}. Best is trial 12 with value: 106.1645504217598.
# Best XGB params: {'n_estimators': 488, 'max_depth': 7, 'learning_rate': 0.0465993926653307, 'subsample': 0.6903876261245432, 'colsample_bytree': 0.8873702240299636}
#
# XGBoost Regressor --> RMSE: 106.1646, R2: 0.7594

# %%
# Save the best model
joblib.dump(best_xgb, "../../models/best_xgb_regressor_model.pkl")
# Out:
# ['../../models/best_xgb_regressor_model.pkl']
